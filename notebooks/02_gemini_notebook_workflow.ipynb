# %% [markdown]
# # 02 — Gemini Notebook Workflow
#
# Generate a source-grounded prompt for Gemini Notebook without using a paid API.

# %% [markdown]
# ## Choose curriculum scope
#
# Start with one P3 topic while testing the workflow.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)

from src.curriculum import get_core_ideas, get_topic_scope_notes

topic_codes = ["P3-INT-MAG"]
selected_los = get_core_ideas(level="P3", topic_codes=topic_codes)
scope = get_topic_scope_notes(topic_codes)

selected_los[["LO_ID","Official Learning Outcome"]]

# %% [markdown]
# ## Build the prompt
#
# Copy the result into a Gemini Notebook containing the relevant MOE syllabus and TLG sources.

# %%
from src.prompt_builder import build_question_generation_prompt

prompt = build_question_generation_prompt(
    selected_los,
    scope,
    candidates_per_lo=5,
    diagnostic_use="Topic",
)

print(prompt)
