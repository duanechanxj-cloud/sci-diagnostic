# %% [markdown]
# # 09 — Longitudinal Tracking
#
# Reserved for comparing the same LO_ID across Topic, Pre-WA and EOY checkpoints using fresh questions.

# %% [markdown]
# ## Future data model
#
# The stable join key is LO_ID, while Diagnostic_ID and date distinguish checkpoints.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)

columns = [
    "Response_ID",
    "Diagnostic_ID",
    "Checkpoint_Date",
    "Diagnostic_Use",
    "LO_ID",
    "Questions",
    "Correct",
    "Percent_Correct",
]
pd.DataFrame(columns=columns)

# %% [markdown]
# ## Design rule
#
# Do not compare only total scores. Track evidence for the same concept over time.

# %%
print("Topic -> Pre-WA -> EOY")
print("Same LO_ID, different approved questions where possible.")
