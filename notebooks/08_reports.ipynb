# %% [markdown]
# # 08 — AI-enabled Reports
#
# Generate teacher-or-parent diagnostic PDFs with a compact topic-performance matrix and optional Gemini-generated interpretation. Gemini receives anonymous question evidence only — not the pupil's name or Response_ID.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.reporting import generate_student_pdf, generate_reports_for_class
from src.gemini_analysis import analyse_student_with_gemini
print('PDF + Gemini report engine imported successfully.')

# %% [markdown]
# ## Gemini privacy boundary
#
# One pupil is analysed per API call. Remove `Response_ID`, `Pupil_Key`, class, index number, school and timestamps before calling Gemini. The API receives only question-level Science evidence.

# %%
# Never paste a real API key into a notebook you plan to save/share.
# Prefer the Streamlit Reports (AI-enabled) page, which uses a password field.
print('Gemini integration is optional; local PDF generation still works without it.')
