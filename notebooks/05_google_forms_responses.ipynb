# %% [markdown]
# # 05 — Google Forms Responses (API / legacy CSV)
#
# Convert Google Forms' wide response spreadsheet into a reliable one-row-per-student-per-question table.

# %% [markdown]
# ## Load files
#
# Keep real response CSVs under private_data/responses on the school laptop.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)

from src.config import RESPONSES_DIR
print("Private response folder:", RESPONSES_DIR)
print("Place exported Google Forms CSV files here.")

# %% [markdown]
# ## Conversion workflow
#
# V2.3 normally uses one class-specific Google Form per class. Each saved Form manifest links the class and Google question IDs to local Question_ID values. Fetch responses through Streamlit for the normal workflow.

# %%
# Example once you have a real export:
#
# responses = pd.read_csv(RESPONSES_DIR / "P3_Magnets_Responses.csv")
# from src.forms import google_forms_wide_to_long, option_text_to_letter
# from src.question_bank import load_question_bank
#
# long = google_forms_wide_to_long(
#     responses,
#     student_id_column="Response ID",
#     student_name_column="Name",
#     timestamp_column="Timestamp",
# )
# bank = load_question_bank()
# long = option_text_to_letter(long, bank)
# long.head()
print("Ready for your first real Google Forms export.")
