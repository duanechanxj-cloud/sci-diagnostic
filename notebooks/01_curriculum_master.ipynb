# %% [markdown]
# # 01 — Curriculum Master
#
# Explore the official MOE curriculum data that controls what the diagnostic is allowed to test.

# %% [markdown]
# ## Load official data
#
# Nothing is generated here. We are simply reading the Concept Master.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)

from src.curriculum import load_concept_master
learning_outcomes, scope_notes, topics = load_concept_master()
learning_outcomes.head()

# %% [markdown]
# ## Inspect P3 Core Ideas
#
# These are the main conceptual targets for the first version.

# %%
from src.curriculum import get_core_ideas
p3_core = get_core_ideas(level="P3")
p3_core[["LO_ID","Topic_Code","Official Learning Outcome","Official Details / Sub-points"]]

# %% [markdown]
# ## Inspect scope boundaries
#
# Read these before approving any generated question.

# %%
scope_notes[scope_notes["Level"].eq("P3")][
    ["Topic_Code","Official Note / Scope Boundary"]
]
