# %% [markdown]
# # 06 — Local Analysis
#
# Score responses and summarise concept evidence locally in Python. No Gemini API is required.

# %% [markdown]
# ## Scoring pipeline
#
# This cell becomes active after Notebook 05 produces `long`.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)

from src.question_bank import load_question_bank
from src.scoring import score_responses, student_lo_summary, class_lo_summary
from src.curriculum import load_concept_master
from src.analysis import add_curriculum_wording, rank_class_revision_priorities

print("The analysis engine is ready.")

# %% [markdown]
# ## Example execution
#
# Uncomment when `long` exists.

# %%
# bank = load_question_bank()
# scored = score_responses(long, bank)
# student_summary = student_lo_summary(scored)
# class_summary = class_lo_summary(scored)
#
# lo, _, _ = load_concept_master()
# student_summary = add_curriculum_wording(student_summary, lo)
# class_priorities = rank_class_revision_priorities(class_summary)
#
# display(student_summary.head())
# display(class_priorities)
print("No student data is bundled with the project.")
