# %% [markdown]
# # 00 — Setup Check
#
# Run this first on any new computer. It checks that the project can see its files and import its shared Python modules.

# %% [markdown]
# ## Find the project
#
# Jupyter notebooks live one folder below the project root.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Check imports
#
# If this cell works, the shared engine is available to every notebook.

# %%
from src.config import CONCEPT_MASTER_PATH, QUESTION_BANK_PATH
from src.curriculum import load_concept_master

print("Concept Master:", CONCEPT_MASTER_PATH.exists())
print("Question Bank:", QUESTION_BANK_PATH.exists())

lo, scope, topics = load_concept_master()
print("Learning Outcome rows:", len(lo))
print("Topic rows:", len(topics))
