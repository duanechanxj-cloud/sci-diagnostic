# %% [markdown]
# # 07 — Anonymise for AI Discussion
#
# Create an anonymised summary you can share for deeper AI interpretation without including student names.

# %% [markdown]
# ## Anonymisation
#
# The local mapping stays on the school computer. The exported file contains pseudonymous IDs.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)

from src.privacy import anonymise_student_data

# Example once student_summary exists:
# anonymised = anonymise_student_data(student_summary)
# anonymised.to_csv(
#     PROJECT_ROOT / "output" / "anonymised_exports" / "summary_for_ai.csv",
#     index=False,
# )
print("Use this stage before sharing analysis outside the school environment.")
